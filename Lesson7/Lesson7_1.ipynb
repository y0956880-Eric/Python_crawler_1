# %%
import nest_asyncio
import asyncio
from crawl4ai import AsyncWebCrawler
nest_asyncio.apply()

async def main():
    async with AsyncWebCrawler() as crawler:
        result = await crawler.arun(
            url="https://example.com")

if __name__ == "__main__":
    asyncio.run(main())
# Out:
# Task exception was never retrieved
# future: <Task finished name='Task-2' coro=<Connection.run() done, defined at c:\Users\User\Documents\GitHub\Python_crawler_1\.venv\lib\site-packages\playwright\_impl\_connection.py:305> exception=NotImplementedError()>
# Traceback (most recent call last):
#   File "C:\Users\User\AppData\Roaming\uv\python\cpython-3.10.19-windows-x86_64-none\lib\asyncio\tasks.py", line 232, in __step
#     result = coro.send(None)
#   File "c:\Users\User\Documents\GitHub\Python_crawler_1\.venv\lib\site-packages\playwright\_impl\_connection.py", line 312, in run
#     await self._transport.connect()
#   File "c:\Users\User\Documents\GitHub\Python_crawler_1\.venv\lib\site-packages\playwright\_impl\_transport.py", line 133, in connect
#     raise exc
#   File "c:\Users\User\Documents\GitHub\Python_crawler_1\.venv\lib\site-packages\playwright\_impl\_transport.py", line 120, in connect
#     self._proc = await asyncio.create_subprocess_exec(
#   File "C:\Users\User\AppData\Roaming\uv\python\cpython-3.10.19-windows-x86_64-none\lib\asyncio\subprocess.py", line 218, in create_subprocess_exec
#     transport, protocol = await loop.subprocess_exec(
#   File "C:\Users\User\AppData\Roaming\uv\python\cpython-3.10.19-windows-x86_64-none\lib\asyncio\base_events.py", line 1681, in subprocess_exec
#     transport = await self._make_subprocess_transport(
#   File "C:\Users\User\AppData\Roaming\uv\python\cpython-3.10.19-windows-x86_64-none\lib\asyncio\base_events.py", line 498, in _make_subprocess_transport
#     raise NotImplementedError
# NotImplementedError
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[1], line 12
#       8         result = await crawler.arun(
#       9             url="https://example.com")
#      11 if __name__ == "__main__":
# ---> 12     asyncio.run(main())
#
# File c:\Users\User\Documents\GitHub\Python_crawler_1\.venv\lib\site-packages\nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File c:\Users\User\Documents\GitHub\Python_crawler_1\.venv\lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~\AppData\Roaming\uv\python\cpython-3.10.19-windows-x86_64-none\lib\asyncio\futures.py:201, in Future.result(self)
#     199 self.__log_traceback = False
#     200 if self._exception is not None:
# --> 201     raise self._exception.with_traceback(self._exception_tb)
#     202 return self._result
#
# File ~\AppData\Roaming\uv\python\cpython-3.10.19-windows-x86_64-none\lib\asyncio\tasks.py:232, in Task.__step(***failed resolving arguments***)
#     228 try:
#     229     if exc is None:
#     230         # We use the `send` method directly, because coroutines
#     231         # don't have `__iter__` and `__next__` methods.
# --> 232         result = coro.send(None)
#     233     else:
#     234         result = coro.throw(exc)
#
# Cell In[1], line 7, in main()
#       6 async def main():
# ----> 7     async with AsyncWebCrawler() as crawler:
#       8         result = await crawler.arun(
#       9             url="https://example.com")
#
# File c:\Users\User\Documents\GitHub\Python_crawler_1\.venv\lib\site-packages\crawl4ai\async_webcrawler.py:194, in AsyncWebCrawler.__aenter__(self)
#     193 async def __aenter__(self):
# --> 194     return await self.start()
#
# File c:\Users\User\Documents\GitHub\Python_crawler_1\.venv\lib\site-packages\crawl4ai\async_webcrawler.py:177, in AsyncWebCrawler.start(self)
#     170 async def start(self):
#     171     """
#     172     Start the crawler explicitly without using context manager.
#     173     This is equivalent to using 'async with' but gives more control over the lifecycle.
#     174     Returns:
#     175         AsyncWebCrawler: The initialized crawler instance
#     176     """
# --> 177     await self.crawler_strategy.__aenter__()
#     178     self.logger.info(f"Crawl4AI {crawl4ai_version}", tag="INIT")
#     179     self.ready = True
#
# File c:\Users\User\Documents\GitHub\Python_crawler_1\.venv\lib\site-packages\crawl4ai\async_crawler_strategy.py:119, in AsyncPlaywrightCrawlerStrategy.__aenter__(self)
#     118 async def __aenter__(self):
# --> 119     await self.start()
#     120     return self
#
# File c:\Users\User\Documents\GitHub\Python_crawler_1\.venv\lib\site-packages\crawl4ai\async_crawler_strategy.py:129, in AsyncPlaywrightCrawlerStrategy.start(self)
#     125 async def start(self):
#     126     """
#     127     Start the browser and initialize the browser manager.
#     128     """
# --> 129     await self.browser_manager.start()
#     130     await self.execute_hook(
#     131         "on_browser_created",
#     132         self.browser_manager.browser,
#     133         context=self.browser_manager.default_context,
#     134     )
#
# File c:\Users\User\Documents\GitHub\Python_crawler_1\.venv\lib\site-packages\crawl4ai\browser_manager.py:659, in BrowserManager.start(self)
#     656     from playwright.async_api import async_playwright
#     658 # Initialize playwright
# --> 659 self.playwright = await async_playwright().start()
#     661 if self.config.cdp_url or self.config.use_managed_browser:
#     662     self.config.use_managed_browser = True
#
# File c:\Users\User\Documents\GitHub\Python_crawler_1\.venv\lib\site-packages\playwright\async_api\_context_manager.py:51, in PlaywrightContextManager.start(self)
#      50 async def start(self) -> AsyncPlaywright:
# ---> 51     return await self.__aenter__()
#
# File c:\Users\User\Documents\GitHub\Python_crawler_1\.venv\lib\site-packages\playwright\async_api\_context_manager.py:46, in PlaywrightContextManager.__aenter__(self)
#      44 if not playwright_future.done():
#      45     playwright_future.cancel()
# ---> 46 playwright = AsyncPlaywright(next(iter(done)).result())
#      47 playwright.stop = self.__aexit__  # type: ignore
#      48 return playwright
#
# File ~\AppData\Roaming\uv\python\cpython-3.10.19-windows-x86_64-none\lib\asyncio\futures.py:201, in Future.result(self)
#     199 self.__log_traceback = False
#     200 if self._exception is not None:
# --> 201     raise self._exception.with_traceback(self._exception_tb)
#     202 return self._result
#
# File c:\Users\User\Documents\GitHub\Python_crawler_1\.venv\lib\site-packages\playwright\_impl\_transport.py:120, in PipeTransport.connect(self)
#     117         startupinfo.wShowWindow = subprocess.SW_HIDE
#     119     executable_path, entrypoint_path = compute_driver_executable()
# --> 120     self._proc = await asyncio.create_subprocess_exec(
#     121         executable_path,
#     122         entrypoint_path,
#     123         "run-driver",
#     124         stdin=asyncio.subprocess.PIPE,
#     125         stdout=asyncio.subprocess.PIPE,
#     126         stderr=_get_stderr_fileno(),
#     127         limit=32768,
#     128         env=env,
#     129         startupinfo=startupinfo,
#     130     )
#     131 except Exception as exc:
#     132     self.on_error_future.set_exception(exc)
#
# File ~\AppData\Roaming\uv\python\cpython-3.10.19-windows-x86_64-none\lib\asyncio\subprocess.py:218, in create_subprocess_exec(program, stdin, stdout, stderr, limit, *args, **kwds)
#     215 loop = events.get_running_loop()
#     216 protocol_factory = lambda: SubprocessStreamProtocol(limit=limit,
#     217                                                     loop=loop)
# --> 218 transport, protocol = await loop.subprocess_exec(
#     219     protocol_factory,
#     220     program, *args,
#     221     stdin=stdin, stdout=stdout,
#     222     stderr=stderr, **kwds)
#     223 return Process(transport, protocol, loop)
#
# File ~\AppData\Roaming\uv\python\cpython-3.10.19-windows-x86_64-none\lib\asyncio\base_events.py:1681, in BaseEventLoop.subprocess_exec(self, protocol_factory, program, stdin, stdout, stderr, universal_newlines, shell, bufsize, encoding, errors, text, *args, **kwargs)
#    1679     debug_log = f'execute program {program!r}'
#    1680     self._log_subprocess(debug_log, stdin, stdout, stderr)
# -> 1681 transport = await self._make_subprocess_transport(
#    1682     protocol, popen_args, False, stdin, stdout, stderr,
#    1683     bufsize, **kwargs)
#    1684 if self._debug and debug_log is not None:
#    1685     logger.info('%s: %r', debug_log, transport)
#
# File ~\AppData\Roaming\uv\python\cpython-3.10.19-windows-x86_64-none\lib\asyncio\base_events.py:498, in BaseEventLoop._make_subprocess_transport(self, protocol, args, shell, stdin, stdout, stderr, bufsize, extra, **kwargs)
#     494 async def _make_subprocess_transport(self, protocol, args, shell,
#     495                                      stdin, stdout, stderr, bufsize,
#     496                                      extra=None, **kwargs):
#     497     """Create subprocess transport."""
# --> 498     raise NotImplementedError
#
# NotImplementedError:
